# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os,glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/RAVDESS.zip' .
# !unzip -q RAVDESS.zip

# %%
sample_rate=48000
def feature_melspectrogram(
    waveform,
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):

    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform,
        sr=sample_rate,
        n_fft=fft,
        win_length=winlen,
        window=window,
        hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2)

    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)

    return melspectrogram

def feature_mfcc(
    waveform,
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform,
        sr=sample_rate,
        n_mfcc=n_mfcc,
        n_fft=fft,
        win_length=winlen,
        window=window,
        #hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2
        )

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1

        # print progress
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')

    # return all features from list of waveforms
    return features

def get_waveforms(file):

    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)

    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform

    # return a single file's waveform
    return waveform_homo

# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
data_path='./Actor_*/*.wav'
def load_data():
  print('hlo')
  emotions=[]
  waveforms=[]
  intensities,genders=[],[]
  file_count=0
  for file in glob.glob(data_path):
    file_name=os.path.basename(file)
    emotion=int(file_name.split("-")[2])
    if emotion==8: emotion=0
    intensity=emotion_attributes[file_name.split("-")[3]]
    if(int((file_name.split("-")[6]).split(".")[0]))%2==0:
      gender='female'
    else:
      gender='male'
    waveform=get_waveforms(file)
    waveforms.append(waveform)
    emotions.append(emotion)
    intensities.append(intensity)
    genders.append(gender)
    file_count+=1
    print('\r'+f' Processed{file_count}/{1440} audio samples',end='')
  return waveforms, emotions, intensities, genders

# %%
waveforms,emotions,intensities,genders=[],[],[],[]
waveforms,emotions,intensities, genders=load_data()
# Out:
# hlo
#  Processed1440/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')

print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %%
train_set, valid_set, test_set=[],[],[]
X_train,X_valid,X_test=[],[],[]
y_train,y_valid,y_test = [],[],[]
waveforms=np.array(waveforms)
for emotion_num in range(len(emotions_dict)):
  emotion_indices=[index for index, emotion in enumerate(emotions) if emotion==emotion_num]
  np.random.seed(69)
  emotion_indices=np.random.permutation(emotion_indices)
  dim=len(emotion_indices)
    # train set is first 80%
  train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
  valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
  test_indices = emotion_indices[int(0.9*dim):]

  X_train.append(waveforms[train_indices,:])
  y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
  X_valid.append(waveforms[valid_indices,:])
  y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
  X_test.append(waveforms[test_indices,:])
  y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets
  train_set.append(train_indices)
  valid_set.append(valid_indices)
  test_set.append(test_indices)
# concatenate, in order, all waveforms back into one array
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

uniques, count=np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %%
train_set, valid_set, test_set=[],[],[]
X_train,X_valid,X_test=[],[],[]
y_train,y_valid,y_test = [],[],[]
waveforms=np.array(waveforms)
for emotion_num in range(len(emotions_dict)):
  emotion_indices=[index for index, emotion in enumerate(emotions) if emotion==emotion_num]
  np.random.seed(69)
  emotion_indices=np.random.permutation(emotion_indices)
  dim=len(emotion_indices)
    # train set is first 80%
  train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
  valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
  test_indices = emotion_indices[int(0.9*dim):]

  X_train.append(waveforms[train_indices,:])
  y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
  X_valid.append(waveforms[valid_indices,:])
  y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
  X_test.append(waveforms[test_indices,:])
  y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets
  train_set.append(train_indices)
  valid_set.append(valid_indices)
  test_set.append(test_indices)
# concatenate, in order, all waveforms back into one array
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

uniques, count=np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')

print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=0, snr_max=30):


    wave_len = len(waveform)


    noise = np.random.normal(size=(multiples, wave_len))


    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant


    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len


    snr = np.random.randint(snr_min, snr_max)


    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise

    return multiple_augmented_waveforms

# %%
def augment_waveforms(waveforms, features, emotions, multiples):

    emotion_count = 0

    added_count = 0
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1

        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)

    return features, emotions

# %%
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 1

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1147/1147 waveforms for 1147/1147 new augmented samples
#
# Validation waveforms:
# Processed 143/143 waveforms for 143/143 new augmented samples
#
# Test waveforms:
# Processed 150/150 waveforms for 150/150 new augmented samples
#
# Native + Augmented Features set: 2880 total, 2294 train, 286 validation, 300 test samples
# 2294 training sample labels, 286 validation sample labels, 300 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveshow(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveshow(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %%
X_train = np.expand_dims(features_train, 1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test, 1)


y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (2294, 1, 40, 282) train, (286, 1, 40, 282) validation, (300, 1, 40, 282) test
# Shape of emotion labels: (2294,) train, (286,) validation, (300,) test

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1))
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(2294, 1, 40, 282), y_train:(2294,)
# X_valid scaled:(286, 1, 40, 282), y_valid:(286,)
# X_test scaled:(300, 1, 40, 282), y_test:(300,)

# %%
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
filename = 'features+labels.npy'

# open file in read mode and read data
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(2294, 1, 40, 282), y_train:(2294,)
# X_valid:(286, 1, 40, 282), y_valid:(286,)
# X_test:(300, 1, 40, 282), y_test:(300,)

# %%
class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__()

        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])

        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4,
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )

        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        self.conv2Dblock1 = nn.Sequential(

            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training

            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16,
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3),
              nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(

            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
             nn.Conv2d(
                in_channels=16,
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        self.fc1_linear = nn.Linear(512*2+40,num_emotions)

        ### Softmax layer for the 8 output logits from final FC linear layer
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
    def forward(self,x):

        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time

        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1)

        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time

        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1)


        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)

        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1)

        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)

        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)

        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)

        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
# !pip install torchinfo
from torchinfo import summary

# need device to instantiate model
device = 'cpu'

# instantiate model for 8 emotions and move to GPU
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
summary(model, input_size=(1,1,40,282))
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# parallel_all_you_want                         [1, 8]                    --
# ├─Sequential: 1-1                             [1, 64, 1, 8]             --
# │    └─Conv2d: 2-1                            [1, 16, 40, 282]          160
# │    └─BatchNorm2d: 2-2                       [1, 16, 40, 282]          32
# │    └─ReLU: 2-3                              [1, 16, 40, 282]          --
# │    └─MaxPool2d: 2-4                         [1, 16, 20, 141]          --
# │    └─Dropout: 2-5                           [1, 16, 20, 141]          --
# │    └─Conv2d: 2-6                            [1, 32, 20, 141]          4,640
# │    └─BatchNorm2d: 2-7                       [1, 32, 20, 141]          64
# │    └─ReLU: 2-8                              [1, 32, 20, 141]          --
# │    └─MaxPool2d: 2-9                         [1, 32, 5, 35]            --
# │    └─Dropout: 2-10                          [1, 32, 5, 35]            --
# │    └─Conv2d: 2-11                           [1, 64, 5, 35]            18,496
# │    └─BatchNorm2d: 2-12                      [1, 64, 5, 35]            128
# │    └─ReLU: 2-13                             [1, 64, 5, 35]            --
# │    └─MaxPool2d: 2-14                        [1, 64, 1, 8]             --
# │    └─Dropout: 2-15                          [1, 64, 1, 8]             --
# ├─Sequential: 1-2                             [1, 64, 1, 8]             --
# │    └─Conv2d: 2-16                           [1, 16, 40, 282]          160
# │    └─BatchNorm2d: 2-17                      [1, 16, 40, 282]          32
# │    └─ReLU: 2-18                             [1, 16, 40, 282]          --
# │    └─MaxPool2d: 2-19                        [1, 16, 20, 141]          --
# │    └─Dropout: 2-20                          [1, 16, 20, 141]          --
# │    └─Conv2d: 2-21                           [1, 32, 20, 141]          4,640
# │    └─BatchNorm2d: 2-22                      [1, 32, 20, 141]          64
# │    └─ReLU: 2-23                             [1, 32, 20, 141]          --
# │    └─MaxPool2d: 2-24                        [1, 32, 5, 35]            --
# │    └─Dropout: 2-25                          [1, 32, 5, 35]            --
# │    └─Conv2d: 2-26                           [1, 64, 5, 35]            18,496
# │    └─BatchNorm2d: 2-27                      [1, 64, 5, 35]            128
# │    └─ReLU: 2-28                             [1, 64, 5, 35]            --
# │    └─MaxPool2d: 2-29                        [1, 64, 1, 8]             --
# │    └─Dropout: 2-30                          [1, 64, 1, 8]             --
# ├─MaxPool2d: 1-3                              [1, 1, 40, 70]            --
# ├─TransformerEncoder: 1-4                     [70, 1, 40]               --
# │    └─ModuleList: 2-31                       --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [70, 1, 40]               48,232
# │    │    └─TransformerEncoderLayer: 3-2      [70, 1, 40]               48,232
# │    │    └─TransformerEncoderLayer: 3-3      [70, 1, 40]               48,232
# │    │    └─TransformerEncoderLayer: 3-4      [70, 1, 40]               48,232
# ├─Linear: 1-5                                 [1, 8]                    8,520
# ├─Softmax: 1-6                                [1, 8]                    --
# ===============================================================================================
# Total params: 248,488
# Trainable params: 248,488
# Non-trainable params: 0
# Total mult-adds (M): 47.93
# ===============================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 10.44
# Params size (MB): 0.89
# Estimated Total Size (MB): 11.37
# ===============================================================================================

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X,Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()

            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            print(predictions.shape, "pred_shape")
            print(Y.shape, "Y_shape")

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):

        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)

            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch+1}: iteration {i}/{num_iterations}',end='')

        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        print(X_valid_tensor.shape)
        print(Y_valid_tensor.shape)
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)

        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)

        # Save checkpoint of the model
        checkpoint_filename = './drive/MyDrive/content/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch+1} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  248488

# %%
# choose number of epochs higher than reasonable so we can manually stop training
num_epochs = 300

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 1: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 1 --- loss:4.058, Epoch accuracy:22.45%, Validation loss:2.145, Validation accuracy:27.27%
# Epoch 2: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 2 --- loss:1.749, Epoch accuracy:33.13%, Validation loss:1.995, Validation accuracy:31.82%
# Epoch 3: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 3 --- loss:1.667, Epoch accuracy:35.66%, Validation loss:1.812, Validation accuracy:39.16%
# Epoch 4: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 4 --- loss:1.561, Epoch accuracy:40.63%, Validation loss:1.805, Validation accuracy:39.86%
# Epoch 5: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 5 --- loss:1.494, Epoch accuracy:42.81%, Validation loss:1.695, Validation accuracy:43.01%
# Epoch 6: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 6 --- loss:1.423, Epoch accuracy:44.42%, Validation loss:1.665, Validation accuracy:41.61%
# Epoch 7: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 7 --- loss:1.363, Epoch accuracy:48.56%, Validation loss:1.592, Validation accuracy:40.91%
# Epoch 8: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 8 --- loss:1.354, Epoch accuracy:48.78%, Validation loss:1.637, Validation accuracy:42.31%
# Epoch 9: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 9 --- loss:1.256, Epoch accuracy:52.75%, Validation loss:1.488, Validation accuracy:48.25%
# Epoch 10: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 10 --- loss:1.234, Epoch accuracy:53.31%, Validation loss:1.557, Validation accuracy:46.50%
# Epoch 11: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 11 --- loss:1.190, Epoch accuracy:56.23%, Validation loss:1.431, Validation accuracy:49.30%
# Epoch 12: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 12 --- loss:1.153, Epoch accuracy:57.98%, Validation loss:1.383, Validation accuracy:52.80%
# Epoch 13: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 13 --- loss:1.112, Epoch accuracy:58.33%, Validation loss:1.259, Validation accuracy:54.20%
# Epoch 14: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 14 --- loss:1.086, Epoch accuracy:59.37%, Validation loss:1.277, Validation accuracy:55.94%
# Epoch 15: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 15 --- loss:1.038, Epoch accuracy:62.25%, Validation loss:1.255, Validation accuracy:56.29%
# Epoch 16: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 16 --- loss:1.023, Epoch accuracy:59.94%, Validation loss:1.381, Validation accuracy:48.60%
# Epoch 17: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 17 --- loss:0.981, Epoch accuracy:64.08%, Validation loss:1.364, Validation accuracy:53.85%
# Epoch 18: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 18 --- loss:0.930, Epoch accuracy:65.91%, Validation loss:1.335, Validation accuracy:52.80%
# Epoch 19: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 19 --- loss:0.915, Epoch accuracy:65.87%, Validation loss:1.393, Validation accuracy:54.90%
# Epoch 20: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 20 --- loss:0.898, Epoch accuracy:67.61%, Validation loss:1.539, Validation accuracy:48.60%
# Epoch 21: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 21 --- loss:0.892, Epoch accuracy:66.13%, Validation loss:1.506, Validation accuracy:51.40%
# Epoch 22: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 22 --- loss:0.844, Epoch accuracy:67.52%, Validation loss:1.213, Validation accuracy:55.94%
# Epoch 23: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 23 --- loss:0.803, Epoch accuracy:69.22%, Validation loss:1.282, Validation accuracy:55.24%
# Epoch 24: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 24 --- loss:0.805, Epoch accuracy:69.18%, Validation loss:1.350, Validation accuracy:54.90%
# Epoch 25: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 25 --- loss:0.757, Epoch accuracy:71.53%, Validation loss:1.229, Validation accuracy:60.84%
# Epoch 26: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 26 --- loss:0.755, Epoch accuracy:71.93%, Validation loss:1.218, Validation accuracy:56.99%
# Epoch 27: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 27 --- loss:0.721, Epoch accuracy:72.97%, Validation loss:1.179, Validation accuracy:61.89%
# Epoch 28: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 28 --- loss:0.692, Epoch accuracy:73.19%, Validation loss:1.147, Validation accuracy:63.64%
# Epoch 29: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 29 --- loss:0.696, Epoch accuracy:72.93%, Validation loss:1.170, Validation accuracy:61.89%
# Epoch 30: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 30 --- loss:0.659, Epoch accuracy:75.46%, Validation loss:1.296, Validation accuracy:59.09%
# Epoch 31: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 31 --- loss:0.652, Epoch accuracy:75.54%, Validation loss:1.346, Validation accuracy:56.99%
# Epoch 32: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 32 --- loss:0.613, Epoch accuracy:76.98%, Validation loss:1.200, Validation accuracy:62.24%
# Epoch 33: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 33 --- loss:0.617, Epoch accuracy:76.11%, Validation loss:1.307, Validation accuracy:56.64%
# Epoch 34: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 34 --- loss:0.621, Epoch accuracy:76.02%, Validation loss:1.360, Validation accuracy:56.29%
# Epoch 35: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 35 --- loss:0.587, Epoch accuracy:77.90%, Validation loss:1.213, Validation accuracy:63.99%
# Epoch 36: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 36 --- loss:0.596, Epoch accuracy:77.59%, Validation loss:1.148, Validation accuracy:64.69%
# Epoch 37: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 37 --- loss:0.531, Epoch accuracy:79.42%, Validation loss:1.430, Validation accuracy:58.39%
# Epoch 38: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 38 --- loss:0.565, Epoch accuracy:79.16%, Validation loss:1.208, Validation accuracy:62.24%
# Epoch 39: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 39 --- loss:0.522, Epoch accuracy:80.51%, Validation loss:1.188, Validation accuracy:63.99%
# Epoch 40: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 40 --- loss:0.526, Epoch accuracy:79.38%, Validation loss:1.175, Validation accuracy:67.83%
# Epoch 41: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 41 --- loss:0.495, Epoch accuracy:80.43%, Validation loss:1.251, Validation accuracy:63.29%
# Epoch 42: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 42 --- loss:0.494, Epoch accuracy:81.34%, Validation loss:1.409, Validation accuracy:56.99%
# Epoch 43: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 43 --- loss:0.485, Epoch accuracy:80.82%, Validation loss:1.268, Validation accuracy:64.34%
# Epoch 44: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 44 --- loss:0.466, Epoch accuracy:82.61%, Validation loss:1.344, Validation accuracy:60.84%
# Epoch 45: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 45 --- loss:0.483, Epoch accuracy:81.08%, Validation loss:1.332, Validation accuracy:61.89%
# Epoch 46: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 46 --- loss:0.441, Epoch accuracy:83.04%, Validation loss:1.371, Validation accuracy:60.49%
# Epoch 47: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 47 --- loss:0.424, Epoch accuracy:84.05%, Validation loss:1.332, Validation accuracy:60.49%
# Epoch 48: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 48 --- loss:0.424, Epoch accuracy:83.87%, Validation loss:1.231, Validation accuracy:66.78%
# Epoch 49: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 49 --- loss:0.405, Epoch accuracy:84.57%, Validation loss:1.386, Validation accuracy:60.84%
# Epoch 50: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 50 --- loss:0.439, Epoch accuracy:82.52%, Validation loss:1.293, Validation accuracy:64.34%
# Epoch 51: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 51 --- loss:0.403, Epoch accuracy:84.44%, Validation loss:1.607, Validation accuracy:62.59%
# Epoch 52: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 52 --- loss:0.386, Epoch accuracy:85.31%, Validation loss:1.260, Validation accuracy:64.69%
# Epoch 53: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 53 --- loss:0.395, Epoch accuracy:84.79%, Validation loss:1.373, Validation accuracy:64.34%
# Epoch 54: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 54 --- loss:0.367, Epoch accuracy:86.27%, Validation loss:1.326, Validation accuracy:62.59%
# Epoch 55: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 55 --- loss:0.380, Epoch accuracy:85.66%, Validation loss:1.477, Validation accuracy:63.29%
# Epoch 56: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 56 --- loss:0.351, Epoch accuracy:86.84%, Validation loss:1.276, Validation accuracy:68.88%
# Epoch 57: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 57 --- loss:0.365, Epoch accuracy:85.40%, Validation loss:1.561, Validation accuracy:56.99%
# Epoch 58: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 58 --- loss:0.354, Epoch accuracy:86.27%, Validation loss:1.504, Validation accuracy:60.84%
# Epoch 59: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 59 --- loss:0.344, Epoch accuracy:86.84%, Validation loss:1.360, Validation accuracy:63.64%
# Epoch 60: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 60 --- loss:0.333, Epoch accuracy:87.49%, Validation loss:1.224, Validation accuracy:67.13%
# Epoch 61: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 61 --- loss:0.317, Epoch accuracy:88.06%, Validation loss:1.335, Validation accuracy:64.69%
# Epoch 62: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 62 --- loss:0.320, Epoch accuracy:87.66%, Validation loss:1.300, Validation accuracy:65.73%
# Epoch 63: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 63 --- loss:0.327, Epoch accuracy:87.71%, Validation loss:1.522, Validation accuracy:59.79%
# Epoch 64: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 64 --- loss:0.312, Epoch accuracy:88.32%, Validation loss:1.318, Validation accuracy:64.69%
# Epoch 65: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 65 --- loss:0.309, Epoch accuracy:88.10%, Validation loss:1.534, Validation accuracy:61.19%
# Epoch 66: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 66 --- loss:0.295, Epoch accuracy:88.84%, Validation loss:1.422, Validation accuracy:62.24%
# Epoch 67: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 67 --- loss:0.278, Epoch accuracy:89.41%, Validation loss:1.621, Validation accuracy:56.64%
# Epoch 68: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 68 --- loss:0.275, Epoch accuracy:89.45%, Validation loss:1.547, Validation accuracy:61.19%
# Epoch 69: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 69 --- loss:0.292, Epoch accuracy:89.10%, Validation loss:1.495, Validation accuracy:60.84%
# Epoch 70: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 70 --- loss:0.297, Epoch accuracy:88.45%, Validation loss:1.457, Validation accuracy:61.89%
# Epoch 71: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 71 --- loss:0.280, Epoch accuracy:89.41%, Validation loss:1.614, Validation accuracy:60.14%
# Epoch 72: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 72 --- loss:0.262, Epoch accuracy:89.71%, Validation loss:1.425, Validation accuracy:65.03%
# Epoch 73: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 73 --- loss:0.232, Epoch accuracy:91.11%, Validation loss:1.442, Validation accuracy:63.99%
# Epoch 74: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 74 --- loss:0.273, Epoch accuracy:89.45%, Validation loss:1.462, Validation accuracy:66.43%
# Epoch 75: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 75 --- loss:0.247, Epoch accuracy:89.93%, Validation loss:1.719, Validation accuracy:61.19%
# Epoch 76: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 76 --- loss:0.270, Epoch accuracy:89.23%, Validation loss:1.551, Validation accuracy:63.99%
# Epoch 77: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 77 --- loss:0.261, Epoch accuracy:89.80%, Validation loss:1.476, Validation accuracy:63.64%
# Epoch 78: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 78 --- loss:0.235, Epoch accuracy:90.67%, Validation loss:1.555, Validation accuracy:61.89%
# Epoch 79: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 79 --- loss:0.233, Epoch accuracy:91.06%, Validation loss:1.475, Validation accuracy:65.38%
# Epoch 80: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 80 --- loss:0.218, Epoch accuracy:91.85%, Validation loss:1.506, Validation accuracy:65.73%
# Epoch 81: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 81 --- loss:0.222, Epoch accuracy:91.28%, Validation loss:1.496, Validation accuracy:60.49%
# Epoch 82: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 82 --- loss:0.221, Epoch accuracy:91.33%, Validation loss:1.494, Validation accuracy:62.24%
# Epoch 83: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 83 --- loss:0.222, Epoch accuracy:91.63%, Validation loss:1.606, Validation accuracy:64.34%
# Epoch 84: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 84 --- loss:0.205, Epoch accuracy:92.63%, Validation loss:1.374, Validation accuracy:67.48%
# Epoch 85: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 85 --- loss:0.200, Epoch accuracy:92.11%, Validation loss:1.401, Validation accuracy:63.64%
# Epoch 86: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 86 --- loss:0.197, Epoch accuracy:92.11%, Validation loss:1.395, Validation accuracy:64.69%
# Epoch 87: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 87 --- loss:0.194, Epoch accuracy:92.68%, Validation loss:1.559, Validation accuracy:63.64%
# Epoch 88: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 88 --- loss:0.207, Epoch accuracy:92.50%, Validation loss:1.497, Validation accuracy:65.38%
# Epoch 89: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 89 --- loss:0.210, Epoch accuracy:91.11%, Validation loss:1.415, Validation accuracy:67.48%
# Epoch 90: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 90 --- loss:0.205, Epoch accuracy:92.46%, Validation loss:1.562, Validation accuracy:61.19%
# Epoch 91: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 91 --- loss:0.184, Epoch accuracy:92.02%, Validation loss:1.601, Validation accuracy:63.64%
# Epoch 92: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 92 --- loss:0.193, Epoch accuracy:92.42%, Validation loss:1.490, Validation accuracy:65.03%
# Epoch 93: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 93 --- loss:0.170, Epoch accuracy:93.24%, Validation loss:1.600, Validation accuracy:60.84%
# Epoch 94: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 94 --- loss:0.175, Epoch accuracy:93.46%, Validation loss:1.633, Validation accuracy:61.19%
# Epoch 95: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 95 --- loss:0.223, Epoch accuracy:90.58%, Validation loss:1.737, Validation accuracy:63.29%
# Epoch 96: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 96 --- loss:0.203, Epoch accuracy:92.02%, Validation loss:1.766, Validation accuracy:58.04%
# Epoch 97: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 97 --- loss:0.179, Epoch accuracy:92.94%, Validation loss:1.645, Validation accuracy:63.99%
# Epoch 98: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 98 --- loss:0.167, Epoch accuracy:93.59%, Validation loss:1.475, Validation accuracy:64.34%
# Epoch 99: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 99 --- loss:0.194, Epoch accuracy:93.07%, Validation loss:1.510, Validation accuracy:61.54%
# Epoch 100: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 100 --- loss:0.183, Epoch accuracy:92.89%, Validation loss:1.755, Validation accuracy:60.49%
# Epoch 101: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 101 --- loss:0.160, Epoch accuracy:93.77%, Validation loss:1.523, Validation accuracy:65.03%
# Epoch 102: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 102 --- loss:0.175, Epoch accuracy:92.89%, Validation loss:1.685, Validation accuracy:63.29%
# Epoch 103: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 103 --- loss:0.171, Epoch accuracy:93.20%, Validation loss:1.585, Validation accuracy:65.73%
# Epoch 104: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 104 --- loss:0.143, Epoch accuracy:94.59%, Validation loss:1.603, Validation accuracy:63.29%
# Epoch 105: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 105 --- loss:0.128, Epoch accuracy:95.51%, Validation loss:1.679, Validation accuracy:64.34%
# Epoch 106: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 106 --- loss:0.133, Epoch accuracy:95.03%, Validation loss:1.544, Validation accuracy:68.18%
# Epoch 107: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 107 --- loss:0.148, Epoch accuracy:93.90%, Validation loss:1.583, Validation accuracy:63.99%
# Epoch 108: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 108 --- loss:0.139, Epoch accuracy:94.99%, Validation loss:1.783, Validation accuracy:62.94%
# Epoch 109: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 109 --- loss:0.156, Epoch accuracy:94.29%, Validation loss:1.553, Validation accuracy:65.38%
# Epoch 110: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 110 --- loss:0.130, Epoch accuracy:94.90%, Validation loss:1.613, Validation accuracy:65.73%
# Epoch 111: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 111 --- loss:0.133, Epoch accuracy:94.99%, Validation loss:1.818, Validation accuracy:61.54%
# Epoch 112: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 112 --- loss:0.130, Epoch accuracy:95.16%, Validation loss:1.656, Validation accuracy:63.99%
# Epoch 113: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 113 --- loss:0.148, Epoch accuracy:94.38%, Validation loss:1.824, Validation accuracy:63.99%
# Epoch 114: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 114 --- loss:0.145, Epoch accuracy:94.12%, Validation loss:1.543, Validation accuracy:67.48%
# Epoch 115: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 115 --- loss:0.119, Epoch accuracy:95.68%, Validation loss:1.598, Validation accuracy:65.38%
# Epoch 116: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 116 --- loss:0.128, Epoch accuracy:95.12%, Validation loss:1.661, Validation accuracy:63.64%
# Epoch 117: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 117 --- loss:0.138, Epoch accuracy:94.42%, Validation loss:1.575, Validation accuracy:65.38%
# Epoch 118: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 118 --- loss:0.144, Epoch accuracy:94.12%, Validation loss:1.512, Validation accuracy:65.03%
# Epoch 119: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 119 --- loss:0.117, Epoch accuracy:95.51%, Validation loss:1.729, Validation accuracy:62.24%
# Epoch 120: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 120 --- loss:0.138, Epoch accuracy:94.29%, Validation loss:1.780, Validation accuracy:61.54%
# Epoch 121: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 121 --- loss:0.116, Epoch accuracy:95.90%, Validation loss:1.722, Validation accuracy:65.73%
# Epoch 122: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 122 --- loss:0.112, Epoch accuracy:95.82%, Validation loss:1.561, Validation accuracy:66.43%
# Epoch 123: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 123 --- loss:0.112, Epoch accuracy:95.73%, Validation loss:1.684, Validation accuracy:65.38%
# Epoch 124: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 124 --- loss:0.143, Epoch accuracy:94.55%, Validation loss:1.862, Validation accuracy:59.44%
# Epoch 125: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 125 --- loss:0.119, Epoch accuracy:95.47%, Validation loss:1.637, Validation accuracy:65.38%
# Epoch 126: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 126 --- loss:0.124, Epoch accuracy:94.99%, Validation loss:1.735, Validation accuracy:64.69%
# Epoch 127: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 127 --- loss:0.119, Epoch accuracy:95.47%, Validation loss:1.551, Validation accuracy:67.13%
# Epoch 128: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 128 --- loss:0.120, Epoch accuracy:95.12%, Validation loss:1.662, Validation accuracy:65.38%
# Epoch 129: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 129 --- loss:0.115, Epoch accuracy:95.34%, Validation loss:1.672, Validation accuracy:65.38%
# Epoch 130: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 130 --- loss:0.105, Epoch accuracy:95.68%, Validation loss:1.733, Validation accuracy:64.69%
# Epoch 131: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 131 --- loss:0.100, Epoch accuracy:96.03%, Validation loss:1.781, Validation accuracy:63.64%
# Epoch 132: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 132 --- loss:0.091, Epoch accuracy:96.43%, Validation loss:1.732, Validation accuracy:63.99%
# Epoch 133: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 133 --- loss:0.119, Epoch accuracy:95.07%, Validation loss:1.766, Validation accuracy:61.19%
# Epoch 134: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 134 --- loss:0.101, Epoch accuracy:96.03%, Validation loss:1.694, Validation accuracy:66.43%
# Epoch 135: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 135 --- loss:0.098, Epoch accuracy:96.21%, Validation loss:1.702, Validation accuracy:63.99%
# Epoch 136: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 136 --- loss:0.076, Epoch accuracy:96.86%, Validation loss:1.690, Validation accuracy:66.08%
# Epoch 137: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 137 --- loss:0.091, Epoch accuracy:96.34%, Validation loss:1.905, Validation accuracy:61.19%
# Epoch 138: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 138 --- loss:0.088, Epoch accuracy:96.95%, Validation loss:1.765, Validation accuracy:62.94%
# Epoch 139: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 139 --- loss:0.119, Epoch accuracy:95.47%, Validation loss:1.759, Validation accuracy:62.59%
# Epoch 140: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 140 --- loss:0.104, Epoch accuracy:95.60%, Validation loss:1.719, Validation accuracy:65.73%
# Epoch 141: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 141 --- loss:0.097, Epoch accuracy:96.08%, Validation loss:1.809, Validation accuracy:62.59%
# Epoch 142: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 142 --- loss:0.080, Epoch accuracy:96.82%, Validation loss:1.695, Validation accuracy:65.73%
# Epoch 143: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 143 --- loss:0.082, Epoch accuracy:96.56%, Validation loss:1.915, Validation accuracy:63.29%
# Epoch 144: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 144 --- loss:0.095, Epoch accuracy:95.86%, Validation loss:1.874, Validation accuracy:62.94%
# Epoch 145: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 145 --- loss:0.095, Epoch accuracy:95.99%, Validation loss:1.875, Validation accuracy:64.34%
# Epoch 146: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 146 --- loss:0.087, Epoch accuracy:96.77%, Validation loss:1.837, Validation accuracy:62.59%
# Epoch 147: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 147 --- loss:0.085, Epoch accuracy:96.60%, Validation loss:1.657, Validation accuracy:63.64%
# Epoch 148: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 148 --- loss:0.093, Epoch accuracy:96.51%, Validation loss:1.914, Validation accuracy:61.89%
# Epoch 149: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 149 --- loss:0.087, Epoch accuracy:96.77%, Validation loss:1.643, Validation accuracy:66.78%
# Epoch 150: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 150 --- loss:0.076, Epoch accuracy:96.69%, Validation loss:1.731, Validation accuracy:65.03%
# Epoch 151: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 151 --- loss:0.101, Epoch accuracy:96.12%, Validation loss:1.802, Validation accuracy:65.03%
# Epoch 152: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 152 --- loss:0.103, Epoch accuracy:96.25%, Validation loss:1.940, Validation accuracy:60.84%
# Epoch 153: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 153 --- loss:0.092, Epoch accuracy:96.47%, Validation loss:1.696, Validation accuracy:66.43%
# Epoch 154: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 154 --- loss:0.088, Epoch accuracy:96.56%, Validation loss:1.769, Validation accuracy:64.69%
# Epoch 155: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 155 --- loss:0.081, Epoch accuracy:96.82%, Validation loss:1.959, Validation accuracy:64.69%
# Epoch 156: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 156 --- loss:0.089, Epoch accuracy:96.64%, Validation loss:2.053, Validation accuracy:62.94%
# Epoch 157: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 157 --- loss:0.094, Epoch accuracy:96.47%, Validation loss:1.731, Validation accuracy:63.99%
# Epoch 158: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 158 --- loss:0.068, Epoch accuracy:97.21%, Validation loss:1.787, Validation accuracy:65.03%
# Epoch 159: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 159 --- loss:0.082, Epoch accuracy:96.64%, Validation loss:1.790, Validation accuracy:63.29%
# Epoch 160: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 160 --- loss:0.073, Epoch accuracy:97.04%, Validation loss:1.715, Validation accuracy:65.03%
# Epoch 161: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 161 --- loss:0.062, Epoch accuracy:97.43%, Validation loss:1.762, Validation accuracy:66.08%
# Epoch 162: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 162 --- loss:0.080, Epoch accuracy:96.56%, Validation loss:1.799, Validation accuracy:63.29%
# Epoch 163: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 163 --- loss:0.079, Epoch accuracy:96.82%, Validation loss:1.750, Validation accuracy:64.34%
# Epoch 164: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 164 --- loss:0.071, Epoch accuracy:97.17%, Validation loss:1.702, Validation accuracy:65.38%
# Epoch 165: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 165 --- loss:0.102, Epoch accuracy:95.90%, Validation loss:1.830, Validation accuracy:63.99%
# Epoch 166: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 166 --- loss:0.072, Epoch accuracy:97.08%, Validation loss:1.994, Validation accuracy:63.29%
# Epoch 167: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 167 --- loss:0.073, Epoch accuracy:97.30%, Validation loss:1.754, Validation accuracy:65.03%
# Epoch 168: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 168 --- loss:0.073, Epoch accuracy:97.04%, Validation loss:1.830, Validation accuracy:62.94%
# Epoch 169: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 169 --- loss:0.076, Epoch accuracy:96.77%, Validation loss:1.782, Validation accuracy:66.08%
# Epoch 170: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 170 --- loss:0.080, Epoch accuracy:96.60%, Validation loss:2.092, Validation accuracy:61.19%
# Epoch 171: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 171 --- loss:0.077, Epoch accuracy:96.47%, Validation loss:1.886, Validation accuracy:61.89%
# Epoch 172: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 172 --- loss:0.079, Epoch accuracy:96.73%, Validation loss:1.830, Validation accuracy:64.34%
# Epoch 173: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 173 --- loss:0.065, Epoch accuracy:97.43%, Validation loss:1.785, Validation accuracy:66.43%
# Epoch 174: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 174 --- loss:0.075, Epoch accuracy:96.90%, Validation loss:1.710, Validation accuracy:65.38%
# Epoch 175: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 175 --- loss:0.071, Epoch accuracy:97.43%, Validation loss:1.821, Validation accuracy:66.78%
# Epoch 176: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 176 --- loss:0.080, Epoch accuracy:96.77%, Validation loss:1.899, Validation accuracy:63.99%
# Epoch 177: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 177 --- loss:0.073, Epoch accuracy:97.04%, Validation loss:1.785, Validation accuracy:63.99%
# Epoch 178: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 178 --- loss:0.081, Epoch accuracy:96.73%, Validation loss:1.917, Validation accuracy:62.94%
# Epoch 179: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 179 --- loss:0.068, Epoch accuracy:97.12%, Validation loss:1.877, Validation accuracy:62.24%
# Epoch 180: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 180 --- loss:0.067, Epoch accuracy:97.21%, Validation loss:1.879, Validation accuracy:64.34%
# Epoch 181: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 181 --- loss:0.076, Epoch accuracy:96.73%, Validation loss:1.765, Validation accuracy:64.69%
# Epoch 182: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 182 --- loss:0.120, Epoch accuracy:94.77%, Validation loss:1.871, Validation accuracy:61.54%
# Epoch 183: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 183 --- loss:0.081, Epoch accuracy:96.60%, Validation loss:1.947, Validation accuracy:62.24%
# Epoch 184: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 184 --- loss:0.084, Epoch accuracy:96.38%, Validation loss:1.669, Validation accuracy:65.03%
# Epoch 185: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 185 --- loss:0.055, Epoch accuracy:97.91%, Validation loss:1.834, Validation accuracy:61.54%
# Epoch 186: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 186 --- loss:0.067, Epoch accuracy:97.34%, Validation loss:1.748, Validation accuracy:64.34%
# Epoch 187: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 187 --- loss:0.060, Epoch accuracy:97.56%, Validation loss:1.720, Validation accuracy:63.29%
# Epoch 188: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 188 --- loss:0.059, Epoch accuracy:97.34%, Validation loss:1.845, Validation accuracy:63.64%
# Epoch 189: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 189 --- loss:0.066, Epoch accuracy:97.25%, Validation loss:1.816, Validation accuracy:65.03%
# Epoch 190: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 190 --- loss:0.052, Epoch accuracy:97.99%, Validation loss:1.821, Validation accuracy:65.73%
# Epoch 191: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 191 --- loss:0.074, Epoch accuracy:97.17%, Validation loss:1.957, Validation accuracy:60.49%
# Epoch 192: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 192 --- loss:0.107, Epoch accuracy:95.64%, Validation loss:1.934, Validation accuracy:61.89%
# Epoch 193: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 193 --- loss:0.080, Epoch accuracy:96.64%, Validation loss:2.015, Validation accuracy:62.59%
# Epoch 194: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 194 --- loss:0.071, Epoch accuracy:96.77%, Validation loss:1.639, Validation accuracy:64.34%
# Epoch 195: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 195 --- loss:0.069, Epoch accuracy:97.12%, Validation loss:1.985, Validation accuracy:63.64%
# Epoch 196: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 196 --- loss:0.058, Epoch accuracy:97.73%, Validation loss:1.700, Validation accuracy:66.78%
# Epoch 197: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 197 --- loss:0.055, Epoch accuracy:97.91%, Validation loss:1.895, Validation accuracy:65.03%
# Epoch 198: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 198 --- loss:0.050, Epoch accuracy:97.91%, Validation loss:1.841, Validation accuracy:65.73%
# Epoch 199: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 199 --- loss:0.071, Epoch accuracy:96.99%, Validation loss:1.925, Validation accuracy:61.19%
# Epoch 200: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 200 --- loss:0.056, Epoch accuracy:97.47%, Validation loss:1.782, Validation accuracy:65.38%
# Epoch 201: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 201 --- loss:0.058, Epoch accuracy:97.25%, Validation loss:1.781, Validation accuracy:66.08%
# Epoch 202: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 202 --- loss:0.066, Epoch accuracy:97.30%, Validation loss:1.839, Validation accuracy:64.69%
# Epoch 203: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 203 --- loss:0.057, Epoch accuracy:97.73%, Validation loss:1.971, Validation accuracy:63.29%
# Epoch 204: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 204 --- loss:0.047, Epoch accuracy:98.17%, Validation loss:1.826, Validation accuracy:65.03%
# Epoch 205: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 205 --- loss:0.055, Epoch accuracy:97.65%, Validation loss:1.910, Validation accuracy:63.29%
# Epoch 206: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 206 --- loss:0.059, Epoch accuracy:97.47%, Validation loss:1.945, Validation accuracy:62.94%
# Epoch 207: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 207 --- loss:0.064, Epoch accuracy:97.17%, Validation loss:1.934, Validation accuracy:63.64%
# Epoch 208: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 208 --- loss:0.061, Epoch accuracy:97.38%, Validation loss:1.951, Validation accuracy:62.59%
# Epoch 209: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 209 --- loss:0.060, Epoch accuracy:97.56%, Validation loss:1.976, Validation accuracy:62.59%
# Epoch 210: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 210 --- loss:0.083, Epoch accuracy:96.38%, Validation loss:1.931, Validation accuracy:63.64%
# Epoch 211: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# ...
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 231 --- loss:0.071, Epoch accuracy:96.82%, Validation loss:1.874, Validation accuracy:64.34%
# Epoch 232: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 232 --- loss:0.067, Epoch accuracy:97.34%, Validation loss:1.958, Validation accuracy:60.14%
# Epoch 233: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 233 --- loss:0.057, Epoch accuracy:97.52%, Validation loss:1.886, Validation accuracy:61.89%
# Epoch 234: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 234 --- loss:0.060, Epoch accuracy:97.52%, Validation loss:1.934, Validation accuracy:62.24%
# Epoch 235: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 235 --- loss:0.051, Epoch accuracy:97.78%, Validation loss:1.762, Validation accuracy:65.73%
# Epoch 236: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 236 --- loss:0.060, Epoch accuracy:97.47%, Validation loss:1.850, Validation accuracy:62.94%
# Epoch 237: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 237 --- loss:0.062, Epoch accuracy:97.17%, Validation loss:1.865, Validation accuracy:63.64%
# Epoch 238: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 238 --- loss:0.045, Epoch accuracy:98.13%, Validation loss:1.838, Validation accuracy:62.24%
# Epoch 239: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 239 --- loss:0.053, Epoch accuracy:97.60%, Validation loss:1.817, Validation accuracy:62.94%
# Epoch 240: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 240 --- loss:0.051, Epoch accuracy:97.86%, Validation loss:1.824, Validation accuracy:64.34%
# Epoch 241: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 241 --- loss:0.047, Epoch accuracy:98.21%, Validation loss:1.888, Validation accuracy:62.94%
# Epoch 242: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 242 --- loss:0.041, Epoch accuracy:98.13%, Validation loss:1.930, Validation accuracy:63.99%
# Epoch 243: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 243 --- loss:0.042, Epoch accuracy:98.13%, Validation loss:1.719, Validation accuracy:65.03%
# Epoch 244: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 244 --- loss:0.042, Epoch accuracy:98.21%, Validation loss:1.881, Validation accuracy:63.64%
# Epoch 245: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 245 --- loss:0.049, Epoch accuracy:97.78%, Validation loss:1.875, Validation accuracy:62.59%
# Epoch 246: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 246 --- loss:0.065, Epoch accuracy:97.12%, Validation loss:1.998, Validation accuracy:62.24%
# Epoch 247: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 247 --- loss:0.115, Epoch accuracy:95.25%, Validation loss:1.828, Validation accuracy:64.34%
# Epoch 248: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 248 --- loss:0.081, Epoch accuracy:96.64%, Validation loss:2.237, Validation accuracy:60.84%
# Epoch 249: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 249 --- loss:0.107, Epoch accuracy:95.55%, Validation loss:1.816, Validation accuracy:63.99%
# Epoch 250: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 250 --- loss:0.045, Epoch accuracy:98.04%, Validation loss:1.804, Validation accuracy:63.29%
# Epoch 251: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 251 --- loss:0.055, Epoch accuracy:97.65%, Validation loss:1.822, Validation accuracy:65.73%
# Epoch 252: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 252 --- loss:0.049, Epoch accuracy:98.08%, Validation loss:1.933, Validation accuracy:63.99%
# Epoch 253: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 253 --- loss:0.044, Epoch accuracy:97.99%, Validation loss:2.024, Validation accuracy:61.19%
# Epoch 254: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 254 --- loss:0.046, Epoch accuracy:97.99%, Validation loss:1.842, Validation accuracy:62.24%
# Epoch 255: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 255 --- loss:0.069, Epoch accuracy:96.86%, Validation loss:1.848, Validation accuracy:61.89%
# Epoch 256: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 256 --- loss:0.052, Epoch accuracy:97.43%, Validation loss:1.871, Validation accuracy:65.38%
# Epoch 257: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 257 --- loss:0.043, Epoch accuracy:97.95%, Validation loss:1.839, Validation accuracy:64.34%
# Epoch 258: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 258 --- loss:0.049, Epoch accuracy:97.86%, Validation loss:2.041, Validation accuracy:60.84%
# Epoch 259: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 259 --- loss:0.054, Epoch accuracy:97.73%, Validation loss:1.733, Validation accuracy:65.38%
# Epoch 260: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 260 --- loss:0.050, Epoch accuracy:97.82%, Validation loss:1.862, Validation accuracy:63.64%
# Epoch 261: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 261 --- loss:0.071, Epoch accuracy:96.90%, Validation loss:1.781, Validation accuracy:65.38%
# Epoch 262: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 262 --- loss:0.057, Epoch accuracy:97.56%, Validation loss:1.838, Validation accuracy:64.69%
# Epoch 263: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 263 --- loss:0.047, Epoch accuracy:98.08%, Validation loss:1.866, Validation accuracy:63.29%
# Epoch 264: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 264 --- loss:0.062, Epoch accuracy:97.38%, Validation loss:2.041, Validation accuracy:60.14%
# Epoch 265: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 265 --- loss:0.101, Epoch accuracy:95.47%, Validation loss:1.732, Validation accuracy:65.73%
# Epoch 266: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 266 --- loss:0.062, Epoch accuracy:97.38%, Validation loss:2.183, Validation accuracy:60.49%
# Epoch 267: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 267 --- loss:0.055, Epoch accuracy:97.52%, Validation loss:1.962, Validation accuracy:61.19%
# Epoch 268: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 268 --- loss:0.058, Epoch accuracy:97.38%, Validation loss:1.769, Validation accuracy:66.08%
# Epoch 269: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 269 --- loss:0.040, Epoch accuracy:98.13%, Validation loss:1.908, Validation accuracy:65.03%
# Epoch 270: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 270 --- loss:0.053, Epoch accuracy:97.65%, Validation loss:1.981, Validation accuracy:62.24%
# Epoch 271: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 271 --- loss:0.050, Epoch accuracy:97.69%, Validation loss:2.058, Validation accuracy:62.24%
# Epoch 272: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 272 --- loss:0.084, Epoch accuracy:96.51%, Validation loss:1.764, Validation accuracy:65.73%
# Epoch 273: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 273 --- loss:0.066, Epoch accuracy:97.04%, Validation loss:1.807, Validation accuracy:65.03%
# Epoch 274: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 274 --- loss:0.038, Epoch accuracy:98.39%, Validation loss:1.832, Validation accuracy:63.29%
# Epoch 275: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 275 --- loss:0.047, Epoch accuracy:97.99%, Validation loss:1.772, Validation accuracy:63.29%
# Epoch 276: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 276 --- loss:0.046, Epoch accuracy:98.17%, Validation loss:1.865, Validation accuracy:62.94%
# Epoch 277: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 277 --- loss:0.046, Epoch accuracy:97.73%, Validation loss:1.820, Validation accuracy:63.99%
# Epoch 278: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 278 --- loss:0.048, Epoch accuracy:97.95%, Validation loss:1.766, Validation accuracy:65.03%
# Epoch 279: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 279 --- loss:0.041, Epoch accuracy:98.21%, Validation loss:1.864, Validation accuracy:62.94%
# Epoch 280: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 280 --- loss:0.053, Epoch accuracy:97.56%, Validation loss:1.845, Validation accuracy:62.94%
# Epoch 281: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 281 --- loss:0.063, Epoch accuracy:97.47%, Validation loss:1.919, Validation accuracy:65.03%
# Epoch 282: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 282 --- loss:0.062, Epoch accuracy:97.43%, Validation loss:1.822, Validation accuracy:62.94%
# Epoch 283: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 283 --- loss:0.061, Epoch accuracy:97.17%, Validation loss:2.123, Validation accuracy:59.09%
# Epoch 284: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 284 --- loss:0.071, Epoch accuracy:96.82%, Validation loss:1.973, Validation accuracy:63.29%
# Epoch 285: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 285 --- loss:0.081, Epoch accuracy:96.25%, Validation loss:2.088, Validation accuracy:61.54%
# Epoch 286: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 286 --- loss:0.072, Epoch accuracy:96.95%, Validation loss:1.964, Validation accuracy:62.94%
# Epoch 287: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 287 --- loss:0.056, Epoch accuracy:97.65%, Validation loss:1.906, Validation accuracy:65.03%
# Epoch 288: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 288 --- loss:0.056, Epoch accuracy:97.65%, Validation loss:1.806, Validation accuracy:64.34%
# Epoch 289: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 289 --- loss:0.045, Epoch accuracy:97.99%, Validation loss:1.994, Validation accuracy:62.24%
# Epoch 290: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 290 --- loss:0.076, Epoch accuracy:96.60%, Validation loss:1.998, Validation accuracy:63.29%
# Epoch 291: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 291 --- loss:0.083, Epoch accuracy:96.08%, Validation loss:1.954, Validation accuracy:61.89%
# Epoch 292: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 292 --- loss:0.081, Epoch accuracy:96.38%, Validation loss:2.022, Validation accuracy:61.19%
# Epoch 293: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 293 --- loss:0.058, Epoch accuracy:97.56%, Validation loss:1.911, Validation accuracy:62.59%
# Epoch 294: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 294 --- loss:0.048, Epoch accuracy:97.91%, Validation loss:1.779, Validation accuracy:64.69%
# Epoch 295: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 295 --- loss:0.036, Epoch accuracy:98.43%, Validation loss:1.730, Validation accuracy:66.08%
# Epoch 296: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 296 --- loss:0.040, Epoch accuracy:98.21%, Validation loss:1.747, Validation accuracy:66.43%
# Epoch 297: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 297 --- loss:0.041, Epoch accuracy:98.34%, Validation loss:1.933, Validation accuracy:63.99%
# Epoch 298: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 298 --- loss:0.077, Epoch accuracy:96.60%, Validation loss:1.870, Validation accuracy:63.64%
# Epoch 299: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 299 --- loss:0.040, Epoch accuracy:98.21%, Validation loss:1.901, Validation accuracy:61.89%
# Epoch 300: iteration 70/71torch.Size([286, 1, 40, 282])
# torch.Size([286])
# torch.Size([286]) pred_shape
# torch.Size([286]) Y_shape
#
# Epoch 300 --- loss:0.069, Epoch accuracy:96.90%, Validation loss:1.962, Validation accuracy:63.64%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()
#plt.title('Accuracy Curve for Parallel is All You Want Model')
#plt.ylabel('Accuracy', fontsize=16)
#plt.xlabel('Epoch', fontsize=16)
#plt.legend(['Epoch accuracy', 'Epoch'])
#plt.plot(epoch[:],'o')
#plt.plot(epoch_acc[:],'p')
#plt.grid(True)
#plt.show()

# %%
# pick load folder
load_folder = './drive/MyDrive/content/checkpoints'

# pick the epoch to load
epoch = '299'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from ./drive/MyDrive/content/checkpoints/parallel_all_you_wantFINAL-299.pkl

# %%
if torch.cuda.is_available():
    model.cuda()
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# torch.Size([300]) pred_shape
# torch.Size([300]) Y_shape
# Test accuracy is 56.67%

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, matthews_corrcoef


import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()

# %%
f1_micro = f1_score(emotions_groundtruth, predicted_emotions, average='micro')
f1_macro = f1_score(emotions_groundtruth, predicted_emotions, average='macro')
f1_weighted = f1_score(emotions_groundtruth, predicted_emotions, average='weighted')

# Calculate MCC
mcc = matthews_corrcoef(emotions_groundtruth, predicted_emotions)

# Print the F1 score and MCC
print("F1 micro:", f1_micro)
print("F1 macro:", f1_macro)
print("F1 weighted:", f1_weighted)
print("MCC:", mcc)

# %%
from sklearn.metrics import precision_score, recall_score
precision_micro = precision_score(emotions_groundtruth, predicted_emotions, average='micro')
precision_macro = precision_score(emotions_groundtruth, predicted_emotions, average='macro')
precision_weighted = precision_score(emotions_groundtruth, predicted_emotions, average='weighted')

# Calculate recall with averaging
recall_micro = recall_score(emotions_groundtruth, predicted_emotions, average='micro')
recall_macro = recall_score(emotions_groundtruth, predicted_emotions, average='macro')
recall_weighted = recall_score(emotions_groundtruth, predicted_emotions, average='weighted')

# %%
print("Precision micro:", precision_micro)
print("Precision macro:", precision_macro)
print("Precision weighted:", precision_weighted)
print("Recall micro:", recall_micro)
print("Recall macro:", recall_macro)
print("Recall weighted:", recall_weighted)

# %%
plt.title('Accuracy Curve for Parallel is All You Want Model')
plt.ylabel('Accuracy', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.legend(['Epoch accuracy', 'Epoch'])
plt.plot(Epochs[:],'o')
plt.plot(epoch_acc[:],'p')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-857581f1797f> in <cell line: 5>()
#       3 plt.xlabel('Epoch', fontsize=16)
#       4 plt.legend(['Epoch accuracy', 'Epoch'])
# ----> 5 plt.plot(Epochs[:],'o')
#       6 plt.plot(epoch_acc[:],'p')
#       7 plt.grid(True)
#
# NameError: name 'Epochs' is not defined

# %%
print(train_losses)
print(epoch_acc)
